# %%
# !nvidia-smi
# Out:
# Tue Nov 30 14:40:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.29.05    Driver Version: 495.29.05    CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0 Off |                  N/A |
# | 30%   34C    P8    22W / 350W |     23MiB / 24267MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    On   | 00000000:21:00.0 Off |                  Off |
# | 56%   82C    P2   225W / 230W |   9973MiB / 24256MiB |     82%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    On   | 00000000:4B:00.0 Off |                  Off |
# | 30%   34C    P8    23W / 230W |      8MiB / 24256MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    On   | 00000000:4C:00.0 Off |                  Off |
# | 30%   36C    P8    10W / 230W |   4495MiB / 24256MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2742      G   /usr/lib/xorg/Xorg                  9MiB |
# |    0   N/A  N/A      2847      G   /usr/bin/gnome-shell               12MiB |
# |    1   N/A  N/A      2742      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A     37995      C   ...d_optimisation/bin/python     2007MiB |
# |    1   N/A  N/A     48530      C   python3                          4487MiB |
# |    1   N/A  N/A    120575      C   ...d_optimisation/bin/python     3471MiB |
# |    2   N/A  N/A      2742      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      2742      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A     46664      C   python3                          4487MiB |
# +-----------------------------------------------------------------------------+

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 32

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=8)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=8)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Here we shall plot the number of samples in each class.\
# In CIFAR10 dataset the samples are balanced at 5000 samples per class.\
# We will also define a function long tail that shall convert the\
# balanced dataset into an unbalanced one given a dataset imbalance factor lamda.

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_data_distribution(dataset, keyname="no name", classes=classes):
    dataset_elems = len(classes)*[0]
    for image, label in dataset:
        dataset_elems[label]+=1
    plt.bar(list(classes), dataset_elems)
    plt.title(keyname)
    plt.show()

# %%
import random
def long_tail(dataset, classes=10, lamda=1):
    class_indices = list(range(classes))
    random.shuffle(class_indices)
    class_probs = [lamda ** x for x in class_indices]
    select_list = []
    for i, (img, label) in enumerate(dataset):
        if np.random.binomial(1, class_probs[label]):
            select_list.append(i)
    dataset.data=dataset.data[np.array(select_list)]
    dataset.targets=list(dataset.targets[x] for x in select_list)
    return dataset


imabalanced_trainset = long_tail(trainset, classes=10, lamda = 0.7)
show_data_distribution(imabalanced_trainset, keyname="train dataset")

# %% [markdown]
# In the training loop, we will be providing the optimizer, model,\
# dataloader and the criterion i.e the loss function. We shall\
# calculate a running loss that averages over the entire epoch and logs the same

# %%
def train(trainloader, optimizer, net, criterion, epoch):
    running_loss = 0.0
    net.train()
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        if torch.cuda.is_available():
            inputs, labels = inputs.cuda(), labels.cuda()
        else:
            pass

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss = (running_loss*i + loss.item())/(i + 1)
        
    print("Finished Training Epoch :", epoch, " With the running loss : ", running_loss)
    return net

# %%
def test(testloader, net):
    net.eval()
    output_logs = []
    label_logs = []
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        if torch.cuda.is_available():
            inputs = inputs.cuda()
        else:
            pass
        
        labels = labels.numpy()
        outputs = torch.argmax(net(inputs), dim=1).cpu().detach().numpy()
        output_logs.append(outputs)
        label_logs.append(labels)
    print("Finished testing")
    return (np.concatenate(output_logs, axis=0), np.concatenate(label_logs, axis=0))

# %% [markdown]
# In the following function we shall feed all the outputs and the labels\
# and the get metrics function shall return the following metrics of performance\
# 1. precision score class wise
# 2. max precision accross all class epochwise
# 3. min precision accross all class epochwise
# 4. mean precision *unweighted
# 5. recall score class wise
# 6. max recall accross all class epochwise
# 7. min recall accross all class epochwise
# 8. mean recall *unweighted
# 8. accuracy accross all class epochwise

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score

def get_metrics(outputs, labels):
    precision = precision_score(labels, outputs, average=None)
    max_precision = np.max(precision)
    min_precision = np.min(precision)
    mean_precision = np.mean(precision)
    
    recall = recall_score(labels, outputs, average=None)
    max_recall = np.max(recall)
    min_recall = np.min(recall)
    mean_recall = np.mean(recall)
    
    accuracy = accuracy_score(labels, outputs)
    return {
            "precision": precision,
            "recall": recall,
            "accuracy": accuracy,
            "max_precision": max_precision,
            "mean_precision": mean_precision,
            "min_precision": min_precision,
            "max_recall": max_recall,
            "mean_recall": mean_recall,
            "min_recall": min_recall
            }

# %%
def loop(trainloader, testloader, net, optimizer, criterion, epochs=50):
    logs = []
    for i in range(epochs):
        net = train(trainloader, optimizer, net, criterion, epoch=i)
        outputs, labels = test(testloader, net)
        metrics = get_metrics(outputs, labels)
        logs.append(metrics)
    return logs

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

def plot_log(logs, lamda, num_classes=10, classes=classes):
    print(classes)
    precision = [x['precision'] for x in logs]
    recall = [x['recall'] for x in logs]
    accuracy = [x['accuracy'] for x in logs]

    len_logs = len(accuracy)

    max_precision = [x['max_precision'] for x in logs]
    min_precision = [x['min_precision'] for x in logs]
    mean_precision = [x['mean_precision'] for x in logs]

    max_recall = [x['max_recall'] for x in logs]
    min_recall = [x['min_recall'] for x in logs]
    mean_recall = [x['mean_recall'] for x in logs]

    plt.plot(list(range(len(max_precision))), max_precision, label = "max_precision")
    plt.plot(list(range(len(min_precision))), min_precision, label = "min_precision")
    plt.plot(list(range(len(mean_precision))), mean_precision, label = "mean_precision")

    plt.plot(list(range(len(max_recall))), max_recall, label = "max_recall")
    plt.plot(list(range(len(min_recall))), min_recall, label = "min_recall")
    plt.plot(list(range(len(mean_recall))), mean_recall, label = "mean_recall")
    
    plt.xlabel('Epochs')
    plt.ylabel('Metric')
    plt.title(' min mean and max precision and recalls for class imbalance rate  '+ str(lamda))
    plt.legend()
    plt.show()
    plt.close()
    
    
    precision = np.array(precision)
    recall = np.array(recall)
    for i in range(num_classes):
        plt.plot(list(range(len_logs)), precision[:, i].tolist(), label = classes[i])
        
    plt.xlabel('Epochs')
    plt.ylabel('Precision classwise')
    plt.title('Class wise precision for lamda = '+ str(lamda))
    plt.legend()
    plt.show()
    plt.close()
    
    for i in range(num_classes):
        plt.plot(list(range(len_logs)), recall[:, i].tolist(), label = classes[i])
        
    plt.xlabel('Epochs')
    plt.ylabel('Recall classwise')
    plt.title('Class wise recall for lamda = '+ str(lamda))
    plt.legend()
    plt.show()
    plt.close()
    
    plt.plot(list(range(len(accuracy))), accuracy, label = "accuracy")
    plt.xlabel('Epochs')
    plt.ylabel('accuracy')
    plt.title('Class wise accuracy for lamda = '+ str(lamda))
    plt.legend()
    plt.show()
    plt.close()

# %%
class Resnet18cifar(torch.nn.Module):
    def __init__(self, num_classes, pretrained=True):
        super().__init__()
        self.resnet18 = torch.hub.load('pytorch/vision:v0.8.0', 'resnet18', pretrained=pretrained)
        self.base = torch.nn.Sequential(*(list(self.resnet18.children())[:-1]))
        self.fc = torch.nn.Linear(512, num_classes)
    def forward(self, x):
        x = self.base(x)
        x = x.reshape((-1, 512))
        x = self.fc(x)
        return x

# %%
import torchvision.transforms as transforms
import torch.optim as optim
import PIL

logs_by_lamda_resnet18_cifar10 = []
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
)
transform = transforms.Compose([
    transforms.Resize(256, PIL.Image.BICUBIC),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])



for lamda in [1.0, 0.95, 0.9, 0.85, 0.8, 0.75]:
    batch_size = 16
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
    testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                           download=True, transform=transform)
    trainset = long_tail(trainset, 10, lamda)
    show_data_distribution(trainset, keyname="train dataset")

    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                             shuffle=False, num_workers=8)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                              shuffle=True, num_workers=8)

    # get some random training images
    dataiter = iter(trainloader)
    images, labels = dataiter.next()

    # show images
    imshow(torchvision.utils.make_grid(images))
    # print labels
    print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
    print("length of trainset", len(trainset))

    net = Resnet18cifar(10, pretrained=False)
    if torch.cuda.is_available():
        net = net.cuda()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

    logs = loop(trainloader, testloader, net, optimizer, criterion, epochs=200)
    logs_by_lamda_resnet18_cifar10_transfer_learning.append({lamda: logs})
# Out:
# /home/harsh/anaconda3/envs/constrained_optimisation/lib/python3.7/site-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Files already downloaded and verified
# Files already downloaded and verified
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /home/harsh/.cache/torch/hub/pytorch_vision_v0.8.0
#  ship horse  deer horse plane   car truck horse   dog   dog   cat horse  ship  bird  ship   cat
# length of trainset 50000
# Finished Training Epoch : 0  With the running loss :  1.5219016370201106
# Finished testing
# Finished Training Epoch : 1  With the running loss :  1.0540665436935435
# Finished testing
# Finished Training Epoch : 2  With the running loss :  0.804923677558898
# Finished testing
# Finished Training Epoch : 3  With the running loss :  0.6467125115227716
# Finished testing
# Finished Training Epoch : 4  With the running loss :  0.5140621116209055
# Finished testing
# Finished Training Epoch : 5  With the running loss :  0.3926265853911646
# Finished testing
# Finished Training Epoch : 6  With the running loss :  0.2952010301792618
# Finished testing
# Finished Training Epoch : 7  With the running loss :  0.21762366946190606
# Finished testing
# Finished Training Epoch : 8  With the running loss :  0.15350720975592724
# Finished testing
# Finished Training Epoch : 9  With the running loss :  0.11050219911400222
# Finished testing
# Finished Training Epoch : 10  With the running loss :  0.09280005471486602
# Finished testing
# Finished Training Epoch : 11  With the running loss :  0.07251097963788558
# Finished testing
# Finished Training Epoch : 12  With the running loss :  0.06314222080259586
# Finished testing
# Finished Training Epoch : 13  With the running loss :  0.05548351386939179
# Finished testing
# Finished Training Epoch : 14  With the running loss :  0.0380628613209026
# Finished testing
# Finished Training Epoch : 15  With the running loss :  0.03931368001263115
# Finished testing
# Finished Training Epoch : 16  With the running loss :  0.030780031088266983
# Finished testing
# Finished Training Epoch : 17  With the running loss :  0.03085630082610528
# Finished testing
# Finished Training Epoch : 18  With the running loss :  0.024097886505462265
# Finished testing
# Finished Training Epoch : 19  With the running loss :  0.020487011400605555
# Finished testing
# Finished Training Epoch : 20  With the running loss :  0.018518935725414177
# Finished testing
# Finished Training Epoch : 21  With the running loss :  0.017984207293717247
# Finished testing
# Finished Training Epoch : 22  With the running loss :  0.017096782259433493
# Finished testing
# Finished Training Epoch : 23  With the running loss :  0.0145876778317627
# Finished testing
# Finished Training Epoch : 24  With the running loss :  0.013327695722263303
# Finished testing
# Finished Training Epoch : 25  With the running loss :  0.00871653707139194
# Finished testing
# Finished Training Epoch : 26  With the running loss :  0.0067633619787637175
# Finished testing
# Finished Training Epoch : 27  With the running loss :  0.007815471481780975
# Finished testing
# Finished Training Epoch : 28  With the running loss :  0.008118424336230837
# Finished testing
# Finished Training Epoch : 29  With the running loss :  0.007501699544939911
# Finished testing
# Finished Training Epoch : 30  With the running loss :  0.008353536475962034
# Finished testing
# Finished Training Epoch : 31  With the running loss :  0.007744279271357078
# Finished testing
# Finished Training Epoch : 32  With the running loss :  0.006586039225354907
# Finished testing
# Finished Training Epoch : 33  With the running loss :  0.007042476805841003
# Finished testing
# Finished Training Epoch : 34  With the running loss :  0.009066185914977645
# Finished testing
# Finished Training Epoch : 35  With the running loss :  0.009667611638114894
# Finished testing
# Finished Training Epoch : 36  With the running loss :  0.01051788106091875
# Finished testing
# Finished Training Epoch : 37  With the running loss :  0.008978739701643333
# Finished testing
# Finished Training Epoch : 38  With the running loss :  0.006160957308791109
# Finished testing
# Finished Training Epoch : 39  With the running loss :  0.004759104518167433
# Finished testing
# Finished Training Epoch : 40  With the running loss :  0.004456609692258788
# Finished testing
# Finished Training Epoch : 41  With the running loss :  0.004407711773377381
# Finished testing
# Finished Training Epoch : 42  With the running loss :  0.0038402646546933142
# Finished testing
# Finished Training Epoch : 43  With the running loss :  0.003962884216483501
# Finished testing
# Finished Training Epoch : 44  With the running loss :  0.003039283595765299
# Finished testing
# Finished Training Epoch : 45  With the running loss :  0.004221744397720839
# Finished testing
# Finished Training Epoch : 46  With the running loss :  0.002337574028473831
# Finished testing
# Finished Training Epoch : 47  With the running loss :  0.002691824304813264
# Finished testing
# Finished Training Epoch : 48  With the running loss :  0.002591183049846368
# Finished testing
# Finished Training Epoch : 49  With the running loss :  0.0023055626986078323
# Finished testing
# Finished Training Epoch : 50  With the running loss :  0.002077612554701079
# Finished testing
# Finished Training Epoch : 51  With the running loss :  0.0016165468595714606
# Finished testing
# Finished Training Epoch : 52  With the running loss :  0.002149961565081322
# Finished testing
# Finished Training Epoch : 53  With the running loss :  0.0014935825281697185
# Finished testing
# Finished Training Epoch : 54  With the running loss :  0.001850252482422441
# Finished testing
# Finished Training Epoch : 55  With the running loss :  0.0013710218927934304
# Finished testing
# Finished Training Epoch : 56  With the running loss :  0.0018844001436118202
# Finished testing
# Finished Training Epoch : 57  With the running loss :  0.0031100831645054835
# Finished testing
# Finished Training Epoch : 58  With the running loss :  0.0024147928622731203
# Finished testing
# Finished Training Epoch : 59  With the running loss :  0.0010907760107814108
# Finished testing
# Finished Training Epoch : 60  With the running loss :  0.0017805114967535704
# Finished testing
# Finished Training Epoch : 61  With the running loss :  0.002021138526144753
# Finished testing
# Finished Training Epoch : 62  With the running loss :  0.001597288026117057
# Finished testing
# Finished Training Epoch : 63  With the running loss :  0.001309607915199083
# Finished testing
# Finished Training Epoch : 64  With the running loss :  0.0014867778003601418
# Finished testing
# Finished Training Epoch : 65  With the running loss :  0.0010961164697883964
# Finished testing
# Finished Training Epoch : 66  With the running loss :  0.0014211559207037306
# Finished testing
# Finished Training Epoch : 67  With the running loss :  0.0013054539644034252
# Finished testing
# Finished Training Epoch : 68  With the running loss :  0.0014803636826411103
# Finished testing
# Finished Training Epoch : 69  With the running loss :  0.0010509825182888008
# Finished testing
# Finished Training Epoch : 70  With the running loss :  0.0012578694744195878
# Finished testing
# Finished Training Epoch : 71  With the running loss :  0.0010050114858449154
# Finished testing
# Finished Training Epoch : 72  With the running loss :  0.0009178071776814709
# Finished testing
# Finished Training Epoch : 73  With the running loss :  0.0007565244912523294
# Finished testing
# Finished Training Epoch : 74  With the running loss :  0.0013580336682800043
# Finished testing
# Finished Training Epoch : 75  With the running loss :  0.0011215451770402785
# Finished testing
# Finished Training Epoch : 76  With the running loss :  0.001027109938499232
# Finished testing
# Finished Training Epoch : 77  With the running loss :  0.001267162506115909
# Finished testing
# Finished Training Epoch : 78  With the running loss :  0.0011417394309917684
# Finished testing
# Finished Training Epoch : 79  With the running loss :  0.0013016702585437465
# Finished testing
# Finished Training Epoch : 80  With the running loss :  0.0011324187050119167
# Finished testing
# Finished Training Epoch : 81  With the running loss :  0.0017345857856150726
# Finished testing
# Finished Training Epoch : 82  With the running loss :  0.0015831185873520144
# Finished testing
# Finished Training Epoch : 83  With the running loss :  0.0009462726402946491
# Finished testing
# Finished Training Epoch : 84  With the running loss :  0.0012125397243734203
# Finished testing
# Finished Training Epoch : 85  With the running loss :  0.001098349261902524
# Finished testing
# Finished Training Epoch : 86  With the running loss :  0.0014297775591093909
# Finished testing
# Finished Training Epoch : 87  With the running loss :  0.001369661503555726
# Finished testing
# Finished Training Epoch : 88  With the running loss :  0.0011147011039895655
# Finished testing
# Finished Training Epoch : 89  With the running loss :  0.0008411206328053583
# Finished testing
# Finished Training Epoch : 90  With the running loss :  0.0034749291639116736
# Finished testing
# Finished Training Epoch : 92  With the running loss :  0.0016617336091103781
# Finished testing
# Finished Training Epoch : 93  With the running loss :  0.0012637794070001647
# Finished testing
# Finished Training Epoch : 94  With the running loss :  0.0016498467688039991
# Finished testing
# Finished Training Epoch : 95  With the running loss :  0.0010196481384373843
# Finished testing
# Finished Training Epoch : 96  With the running loss :  0.0008260772776741573
# Finished testing
# Finished Training Epoch : 97  With the running loss :  0.0009299741024785638
# Finished testing
# Finished Training Epoch : 98  With the running loss :  0.0013298491022191018
# Finished testing
# Finished Training Epoch : 99  With the running loss :  0.0008784161975875933
# Finished testing
# Finished Training Epoch : 100  With the running loss :  0.0014419283213096344
# Finished testing
# Finished Training Epoch : 101  With the running loss :  0.0011665630382911886
# Finished testing
# Finished Training Epoch : 102  With the running loss :  0.002087302616364662

# %%
for lamda in list(logs_by_lamda_resnet18_cifar10_transfer_learning.keys()):
    log = logs_by_lamda_resnet18_cifar10_transfer_learning[lamda]
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
    print("=" * 30)
    print("THIS IS THE RESULT OF ONLY TRAINING A RESNET-18 CLASSIFICATION LAYER")
    print("THE MODEL WAS NOT PRETRAINED")
    print("=" * 30)
    plot_log(log, lamda, num_classes=len(trainset.classes), classes=classes)
# Out:
# Using cache found in /Users/shrinivas/.cache/torch/hub/pytorch_vision_v0.8.0
# torch.Size([1, 512, 1, 1])
